# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhilhello/Adv_DSA-PySnippets/blob/main/14_Linkedlist_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #14

# %% [markdown]
# #(finding the starting point of the loop,---)

# %%
#1 Q
# check weather we have loop or not     #and find the starting point of the loop            #using fast and slow pointer


class node:
  def __init__(self,u):
    self.data =u
    self.next=None
class Linked:
  def __init__(self):
    self.head=None
  def add_back(self,x):
    t=self.head
    while t.next!=None:
      t=t.next
    t.next=node(x)
  def display(self):
    t=self.head
    while t!=None:
      print(t.data,end='->')
      t=t.next
    print("None")

  def has_loop(self):               #finding the loop
    f=self.head
    s=self.head
    while (f!=None and f.next!=None):
      f=f.next.next
      s=s.next
      if(f==s):
        print("has a loop")
        return
    print("no loop")

  # def find_stating_point(self):     # finding the stating point
  #   f=self.head
  #   s=self.head
  #   while (f!=None and f.next!=None):
  #     f=f.next.next
  #     s=s.next
  #     if(f==s):
  #       print("loop")
  #       break                           #my code   #small edit once see
  #     temp=self.head
  #     f=f.next
  #     temp=temp.next
  #     while(f.data!=temp.data):
  #       f=f.next
  #       temp=temp.next
  #     print(temp.data)
  #     return
  #   print("no loop")

  def find_stating_point(self):     # finding the stating point
    f=self.head
    s=self.head
    while (f!=None and f.next!=None):
      f=f.next.next
      s=s.next
      if(f==s):
        print("loop")                   #sir code
        break
    else:
      return "no loop"
    temp=self.head
    while(f!=temp):
      f=f.next
      temp=temp.next
    print(temp.data)
    return

l1 =Linked()
l1.head=node(5)
l1.add_back(2)
l1.add_back(4)
l1.add_back(3)
l1.add_back(6)
l1.add_back(7)
l1.add_back(1)
# l1.add_back(10)     #even numbers
l1.display()
# l1.has_loop()          # op = no loop

print("linked list 2")
l2=Linked()
l2.head=node(100)
l2.head.next=node(200)
l2.head.next.next=node(300)
l2.head.next.next.next=node(400)
l2.head.next.next.next.next=node(500)
l2.head.next.next.next.next.next=l2.head.next.next       #(300)
# l2.display()
l2.has_loop()          # op = loop
l2.find_stating_point()
# Out:
# 5->2->4->3->6->7->1->None
# linked list 2
# has a loop
# loop
# 300

# %%
#Q 2
# it has a loop ,find how many nodes are there in the loop


class node:
  def __init__(self,u):
    self.data =u
    self.next=None
class Linked:
  def __init__(self):
    self.head=None
  def add_back(self,x):
    t=self.head
    while t.next!=None:
      t=t.next
    t.next=node(x)
  def display(self):
    t=self.head
    while t!=None:
      print(t.data,end='->')
      t=t.next
    print("None")


  def find_stating_point(self):     # finding the stating point
    f=self.head
    s=self.head
    while (f!=None and f.next!=None):
      f=f.next.next
      s=s.next
      if(f==s):
        print("loop")                   #sir code
        break
    else:
      return "no loop"
    temp=self.head
    while(f!=temp):
      f=f.next
      temp=temp.next
    print(temp.data)
    return

  # def count_nodes_in_loop(self):
  #   f=self.head
  #   s=self.head
  #   while (f!=None and f.next!=None):
  #     f=f.next.next
  #     s=s.next
  #     if(f==s):
  #       print("loop")
  #       break                           #my code
  #     temp=self.head
  #     f=f.next
  #     temp=temp.next
  #     while(f.data!=temp.data):
  #       f=f.next
  #       temp=temp.next
  #     temp_c=temp.next
  #     count=1
  #     temp=temp.next
  #     while(temp.next!=temp_c):
  #       count+=1
  #       temp=temp.next
  #     print(count)
  #     return
  #   print("no loop")
  # #   return

  def count_nodes_in_loop(self):
    f=self.head
    s=self.head
    while (f!=None and f.next!=None):
      f=f.next.next
      s=s.next
      if(f==s):
        print("loop")
        break
    else:
      return "no loop"
    c=1
    s=s.next
    while(s!=f):
      s=s.next
      c+=1
    return c


l1 =Linked()
l1.head=node(5)
l1.add_back(2)
l1.add_back(4)
l1.add_back(3)
l1.add_back(6)
l1.add_back(7)
l1.add_back(1)
# l1.add_back(10)     #even numbers
l1.display()
# l1.has_loop()          # op = no loop

print("linked list 2")
l2=Linked()
l2.head=node(100)
l2.head.next=node(200)
l2.head.next.next=node(300)
l2.head.next.next.next=node(400)
l2.head.next.next.next.next=node(500)
l2.head.next.next.next.next.next=l2.head.next.next       #(300)
l2.find_stating_point()
l2.count_nodes_in_loop()
# Out:
# 5->2->4->3->6->7->1->None
# linked list 2
# loop
# 300
# loop
# 3

# %%
#Q 3

#dectect the cycle and remove the cycle


class node:
  def __init__(self,u):
    self.data =u
    self.next=None
class Linked:
  def __init__(self):
    self.head=None
  def add_back(self,x):
    t=self.head
    while t.next!=None:
      t=t.next
    t.next=node(x)
  def display(self):
    t=self.head
    while t!=None:
      print(t.data,end='->')
      t=t.next
    print("None")

  def has_loop(self):               #finding the loop
    f=self.head
    s=self.head
    while (f!=None and f.next!=None):
      f=f.next.next
      s=s.next
      if(f==s):
        print("has a loop")
        return
    print("no loop")

  # def find_stating_point(self):     # finding the stating point
  #   f=self.head
  #   s=self.head
  #   while (f!=None and f.next!=None):
  #     f=f.next.next
  #     s=s.next
  #     if(f==s):
  #       print("loop")
  #       break                           #my code   #small edit once see
  #     temp=self.head
  #     f=f.next
  #     temp=temp.next
  #     while(f.data!=temp.data):
  #       f=f.next
  #       temp=temp.next
  #     print(temp.data)
  #     return
  #   print("no loop")

  def find_stating_point(self):     # finding the stating point
    f=self.head
    s=self.head
    while (f!=None and f.next!=None):
      f=f.next.next
      s=s.next
      if(f==s):
        print("loop")                   #sir code
        break
    else:
      return "no loop"
    temp=self.head
    while(f!=temp):
      f=f.next
      temp=temp.next
    print(temp.data)
    return

  def rev_loop(self):
    f=self.head
    s=self.head
    while (f!=None and f.next!=None):
      f=f.next.next
      s=s.next
      if(f==s):
        print("has a loop loop")
        break
    else:
      return "no loop"
    s=self.head
    while(s.next!=f.next):
      s=s.next
      f=f.next
    f.next=None
    return



l1 =Linked()
l1.head=node(5)
l1.add_back(2)
l1.add_back(4)
l1.add_back(3)
l1.add_back(6)
l1.add_back(7)
l1.add_back(1)
# l1.add_back(10)     #even numbers
l1.display()
# l1.has_loop()          # op = no loop

print("linked list 2")
l2=Linked()
l2.head=node(100)
l2.head.next=node(200)
l2.head.next.next=node(300)
l2.head.next.next.next=node(400)
l2.head.next.next.next.next=node(500)
l2.head.next.next.next.next.next=l2.head.next.next       #(300)
# l2.display()
l2.has_loop()          # op = loop
l2.find_stating_point()
l2.rev_loop()
l2.display()
# Out:
# 5->2->4->3->6->7->1->None
# linked list 2
# has a loop
# loop
# 300
# has a loop loop
# 100->200->300->400->500->None

# %%
# from pickle import NONE

# Q 4                        #leetcode 92

# reverse the linked list

class node:
  def __init__(self,u):
    self.data =u
    self.next=None
class Linked:
  def __init__(self):
    self.head=None
  def add_back(self,x):
    t=self.head
    while t.next!=None:
      t=t.next
    t.next=node(x)
  def display(self):
    t=self.head
    while t!=None:
      print(t.data,end='->')
      t=t.next
    print("None")

  # def reverse(self):      #reverse the linked list  #internet
  #   prev=None
  #   curr=self.head
  #   while curr!=None:
  #     next=curr.next
  #     curr.next=prev
  #     prev=curr
  #     curr=next
  #   self.head=prev
  #   return

  # def reverse(self):           #O(2n)   #using stack
  #   temp=self.head
  #   stack=[]
  #   while temp!=None:
  #     stack.append(temp.data)
  #     temp=temp.next
  #   temp=self.head              #tail becomes head
  #   while temp!=None:
  #     temp.data=stack.pop()       #pop
  #     temp=temp.next
  #   return



  # none- 1->2->4->3->6->10->8->None
  # p     c  n
  #       p  c  n
  #          p  c  n         #explain
  def reverse(self):                   #using 3 pointer approch  #prv curr next
    prev=None
    curr=self.head
    n=curr.next
    while curr!=None:  #p!=n or
      curr.next=prev
      prev=curr
      curr=n
      if(curr!=None):
        n=curr.next
    self.head=prev
    return




l1 =Linked()
l1.head=node(1)
l1.add_back(2)
l1.add_back(4)
l1.add_back(3)
l1.add_back(6)
l1.add_back(10)
l1.add_back(8)
# l1.add_back(8)     #even numbers
l1.display()
l1.reverse()
l1.display()
# Out:
# 1->2->4->3->6->10->8->None
# 8->10->6->3->4->2->1->None

# %%
# Q 5

# find the given linked list is panlindrom or not


class node:
  def __init__(self,u):
    self.data =u
    self.next=None
class Linked:
  def __init__(self):
    self.head=None
  def add_back(self,x):
    t=self.head
    while t.next!=None:
      t=t.next
    t.next=node(x)
  def display(self):
    t=self.head
    while t!=None:
      print(t.data,end='->')
      t=t.next
    print("None")

  def palindrom(self):          # panlindrom or not
    f=self.head
    s=self.head
    while (f!=None and f.next!=None):
      f=f.next.next
      pr=s
      s=s.next
    print(s.data)
    p=None             # rev
    c=s
    while(c!=None):
      n=c.next
      c.next=p
      p=c
      c=n
    pr.next=p
    s=self.head
    while(s.data!=p.data):
      if(s.data==p.data):
        s=s.next
        p=p.next
      else:
        print("not palindrom")
        return
    print("palindrom")
    return






l1 =Linked()
l1.head=node(9)
l1.add_back(8)
l1.add_back(4)
l1.add_back(8)
l1.add_back(9)
# l1.add_back(10)
# l1.add_back(8)
l1.display()
l1.palindrom()            #yes
l1.display()

# print("linked list 2")
# l2=Linked()
# l2.head=node(100)
# l2.head.next=node(200)
# l2.head.next.next=node(300)
# l2.head.next.next.next=node(400)
# l2.head.next.next.next.next=node(100)
# l2.head.next.next.next.next.next=node(600)            #no
# l2.display()
# l2.palindrom()
# l2.display()
# Out:
# 9->8->4->8->9->None
# 4
# palindrom
# 9->8->9->8->4->None

# %%
# Q 6
# print the second half reverse


class node:
  def __init__(self,u):
    self.data =u
    self.next=None
class Linked:
  def __init__(self):
    self.head=None
  def add_back(self,x):
    t=self.head
    while t.next!=None:
      t=t.next
    t.next=node(x)
  def display(self):
    t=self.head
    while t!=None:
      print(t.data,end='->')
      t=t.next
    print("None")

  def second_half_reverse(self):           # second half reverse
    f=self.head
    s=self.head
    while (f!=None and f.next!=None):
      f=f.next.next
      pr=s
      s=s.next
    print(s.data)
    p=None               # rev
    c=s
    while(c!=None):
      n=c.next
      c.next=p
      p=c
      c=n
    pr.next=p


# l1 =Linked()
# l1.head=node(1)
# l1.add_back(2)
# l1.add_back(4)
# l1.add_back(3)
# l1.add_back(6)
# l1.add_back(10)
# l1.add_back(8)
# # l1.add_back(8)     #even numbers
# l1.display()

print("linked list 2")
l2=Linked()
l2.head=node(100)
l2.head.next=node(200)
l2.head.next.next=node(300)
l2.head.next.next.next=node(400)
l2.head.next.next.next.next=node(500)
l2.head.next.next.next.next.next=node(600)
l2.display()
l2.second_half_reverse()
l2.display()
# Out:
# linked list 2
# 100->200->300->400->500->600->None
# 400
# 100->200->300->600->500->400->None

# %%
# Q 7                    #leet code 160

# find the intesectting point of 2 linked list              #incomplete code

class node:
  def __init__(self,u):
    self.data =u
    self.next=None
class Linked:
  def __init__(self):
    self.head=None
  def add_back(self,x):
    t=self.head
    while t.next!=None:
      t=t.next
    if(t.data==3):          #
      p=node(x)
      t.next=p
      return             #
    t.next=node(x)
  def display(self):
    t=self.head
    while t!=None:
      print(t.data,end='->')
      t=t.next
    print("None")

  def find_intersection(self):
    t1=self.head
    t2=self.head
    while(t1!=t2):
      # print(t1.data,t2.data)
      if(t1==None):
        t1=t1.next
      else:
        t1=t2.next
      if(t2==None):
        t2=t2.next
      else:
        t2=t1.head
    print(t1.data,t2.data)
    return


l1 =Linked()
l1.head=node(1)
l1.add_back(2)
p=l1.add_back(3)
l1.add_back(4)
l1.add_back(5)
l1.add_back(6)
# l1.display()

# print("linked list 2")
l2=Linked()
l2.head=node(100)
l2.head.next=node(200)
l2.head.next.next=node(300)
l2.head.next.next.next=node(400)
l2.head.next.next.next.next=node(500)
l2.head.next.next.next.next.next=node(600)
l2.display()
l1.display()
l2.find_intersection()
# Out:
# 100->200->300->400->500->600->None
# 1->2->3->4->5->6->None
# 100 100

# %% [markdown]
# #leetcode
#  21. Merge Two Sorted Lists

# %%
# exam
